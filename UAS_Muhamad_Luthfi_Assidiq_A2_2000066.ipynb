# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from matplotlib.ticker import PercentFormatter

# %% [markdown]
# # ***Scatter Plot 1*** Kebutuhan di Tiap Propinsi Setiap Tahunnya

# %%
# memanggil dataset kebutuhan per bulan 2
df = pd.read_csv('/content/kebutuhan_per_bulan_2.csv')

# %%
df
# Out:
#            Propinsi  tahun kebutuhan
# 0              ACEH   2005    619876
# 1    SUMATERA UTARA   2005    547255
# 2    SUMATERA BARAT   2005    501315
# 3              RIAU   2005    551498
# 4             JAMBI   2005    495242
# ..              ...    ...       ...
# 369  SULAWESI BARAT   2015   1981507
# 370          MALUKU   2015   2197450
# 371    MALUKU UTARA   2015   2333166
# 372     PAPUA BARAT   2015   2255113
# 373           PAPUA   2015   2171944
#
# [374 rows x 3 columns]

# %%
plt.figure(figsize=(12, 10))
plt.scatter(df['tahun'], df['Propinsi'], s=50, c='magenta', alpha=0.7)

for i in range(len(df)):
    plt.annotate(df['kebutuhan'][i], (df['tahun'][i], df['Propinsi'][i]), ha='center', va='bottom', fontsize=8)

plt.title('PLOT 1 - Kebutuhan tiap Propinsi setiap Tahunnya', fontsize=18)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Propinsi', fontsize=12)

plt.xticks(rotation=0, fontsize=8)
plt.grid(True, linestyle='--', alpha=1)

plt.tight_layout()
plt.show()

# %% [markdown]
# # ***Scatter Plot 2*** Kebutuhan Pertahun Propinsi Lampung

# %%
df = pd.DataFrame(df)

provinsi_pilihan = 'LAMPUNG'
df_provinsi_pilihan = df.loc[df['Propinsi'] == provinsi_pilihan]

x = df_provinsi_pilihan['tahun']
y = df_provinsi_pilihan['kebutuhan']

plt.title(f'PLOT 2 - Statistik Kebutuhan Propinsi {provinsi_pilihan}')
plt.xlabel("Tahun")
plt.ylabel("Kebutuhan")

plt.scatter(x, y, color='magenta')

plt.xlim(min(x), max(x))
# Menampilkan data provinsi tertentu

plt.show()

# %% [markdown]
# # ***Scatter Plot 3*** Menampilkan Data dari File transaksi2

# %%
df_transaksi = pd.read_csv("/content/transaksi2.csv", names=['date', 'id_product', 'quantity', 'id_penjualan'])
df_transaksi
# Out:
#                      date id_product  quantity  id_penjualan
# 0     2017-05-03 11:43:20      22704        25         15572
# 1     2017-09-04 07:16:20      22081        10         12461
# 2     2017-07-09 11:39:20      22989       100         12590
# 3     2017-03-20 12:18:20      22629        64         16839
# 4     2018-01-24 08:50:20      21615         1         13596
# ...                   ...        ...       ...           ...
# 7464  2018-01-24 09:17:20      22510         1         18156
# 7465  2018-02-02 09:49:20      20771         2         14606
# 7466  2017-03-23 12:52:20      22493        12         17001
# 7467  2017-10-25 10:28:20      23118         2         15856
# 7468  2017-07-19 09:54:20      23184         2         14769
#
# [7469 rows x 4 columns]

# %%
df_transaksi['date'] = pd.to_datetime(df_transaksi['date'])
df_transaksi['year'] = df_transaksi['date'].dt.year
df_transaksi['month'] = df_transaksi['date'].dt.month_name()
df_clean = df_transaksi.loc[df_transaksi['year'] == 2017]
df_clean

plt.title('PLOT 3 - Menampilkan Data dari File Transaksi2')
plt.scatter(df_clean['date'], df_clean['quantity'], color='magenta')

plt.xticks(rotation=90)
plt.xlabel('Date')
plt.ylabel('Quantity')

plt.show()

# %% [markdown]
# # ***Scatter Plot 4*** Menampilkan data pesanan setiap kota pada file SupplyKantor

# %%
df = pd.read_csv('/content/SupplyKantor.csv')

# %%
df
# Out:
#    TanggalPesan        Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 0     30-Mar-17     Jakarta  Richard  Pen Set      62          4990
# 1     07-Apr-17    Surabaya     Nono   Binder      29          1990
# 2     16-Apr-17    Surabaya     Nono  Pen Set      55         12490
# 3     24-Apr-17     Bandung    Susan   Binder      81         19990
# 4     03-May-17    Surabaya    Mamat  Pen Set      42         23950
# 5     11-May-17     Jakarta  Richard   Pencil      35          4990
# 6     20-May-17  Yogyakarta   Jajang     Desk       3        275000
# 7     28-May-17     Bandung    Smith     Desk       2        125000
# 8     06-Jun-17     Bandung     Bobi   Pencil       7          1290
# 9     14-Jun-17     Jakarta  Richard  Pen Set      16         15990
# 10    23-Jun-17  Yogyakarta   Jajang      Pen      76          1990
# 11    01-Jul-17     Bandung   Morgan   Binder      28          8990
# 12    10-Jul-17     Bandung   Thomas   Binder      57         19990
# ...

# %%
x = df['Kota']
y = df['Jumlah']
plt.figure(figsize=(12, 10))
plt.scatter(x, y, color="magenta")

plt.xlabel('Kota')
plt.ylabel('Jumlah')

plt.title('PLOT 4 - Total Jumlah Pesanan dari Setiap Kota')

plt.show()

# %% [markdown]
# # ***Scatter Plot 5*** Menampilkan data jumlah pesanan setiap barang yang ada di Yogyakarta

# %%
data_filtered = df[df['Kota']=='Yogyakarta']
data_filtered
# Out:
#    TanggalPesan        Kota SalesRep   Jenis  Jumlah  Harga Satuan
# 6     20-May-17  Yogyakarta   Jajang    Desk       3        275000
# 10    23-Jun-17  Yogyakarta   Jajang     Pen      76          1990
# 14    27-Jul-17  Yogyakarta   Rachel  Pencil      14          1290
# 20    16-Sep-17  Yogyakarta   Rachel  Binder      28          4990
# 29    01-Dec-17  Yogyakarta   Jajang  Binder       7         19990
# 30    09-Dec-17  Yogyakarta   Jajang  Pencil      56          2990
# 33    04-Jan-18  Yogyakarta   Rachel  Pencil      66          1990
# 34    12-Jan-18  Yogyakarta   Rachel  Pencil      75          1990

# %%
x = data_filtered['Jenis']
y = data_filtered['Jumlah']
plt.figure(figsize=(12, 10))
plt.scatter(x, y, color="magenta")
plt.xlabel('Jenis Barang')
plt.ylabel('Jumlah')

plt.title('PLOT 5 - Jumlah Pesanan dari Kota Yogyakarta')

plt.show()

# %% [markdown]
# # ***Scatter Plot 6*** Menampilkan data pesanan Pencil di berbagai Kota

# %%
data_filtered2 = df[df['Jenis']=='Pencil']
data_filtered2
# Out:
#    TanggalPesan        Kota SalesRep   Jenis  Jumlah  Harga Satuan
# 5     11-May-17     Jakarta  Richard  Pencil      35          4990
# 8     06-Jun-17     Bandung     Bobi  Pencil       7          1290
# 14    27-Jul-17  Yogyakarta   Rachel  Pencil      14          1290
# 19    07-Sep-17     Bandung    Smith  Pencil      67          1290
# 22    02-Oct-17     Jakarta  Richard  Pencil      95          1990
# 26    05-Nov-17    Surabaya     Alex  Pencil      36          4990
# 30    09-Dec-17  Yogyakarta   Jajang  Pencil      56          2990
# 33    04-Jan-18  Yogyakarta   Rachel  Pencil      66          1990
# 34    12-Jan-18  Yogyakarta   Rachel  Pencil      75          1990
# 36    29-Jan-18    Surabaya     Alex  Pencil      90          4990
# 37    07-Feb-18     Bandung     Bobi  Pencil      53          1290
# 38    15-Feb-18     Bandung   Thomas  Pencil      32          1990
# 42    21-Mar-18     Bandung   Morgan  Pencil      90          4990

# %%
x = data_filtered2['Kota']
y = data_filtered2['Jumlah']
plt.figure(figsize=(12, 10))
plt.scatter(x, y, color="magenta")
plt.xlabel('Kota')
plt.ylabel('Jumlah')

plt.title('PLOT 6 - Jumlah Pesanan Pencil di Berbagai Kota')

plt.show()
